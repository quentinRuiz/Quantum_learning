# %% [markdown]
# # Circuits with Many Qubits
#
# ## We've Got It Under Control

# %%
import pennylane as qml
from pennylane import numpy as np

# %% [markdown]
# ### The imposter CZ

# %%
dev = qml.device("default.qubit", wires=2)

# Prepare a two-qubit state; change up the angles if you like
phi, theta, omega = 1.2, 2.3, 3.4


@qml.qnode(device=dev)
def true_cz(phi, theta, omega):
    prepare_states(phi, theta, omega)

    ##################
    # YOUR CODE HERE #
    ##################

    # IMPLEMENT THE REGULAR CZ GATE HERE
    qml.CZ(wires = [0,1])
    return qml.state()


@qml.qnode(dev)
def imposter_cz(phi, theta, omega):
    prepare_states(phi, theta, omega)

    ##################
    # YOUR CODE HERE #
    ##################

    # IMPLEMENT CZ USING ONLY H AND CNOT
    qml.Hadamard(wires = 1)
    qml.CNOT(wires = [0,1])
    qml.Hadamard(wires=1)
    return qml.state()


print(f"True CZ output state {true_cz(phi, theta, omega)}")
print(f"Imposter CZ output state {imposter_cz(phi, theta, omega)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 35
#      31     qml.Hadamard(wires=1)
#      32     return qml.state()
#      33
#      34
# ---> 35 print(f"True CZ output state {true_cz(phi, theta, omega)}")
#      36 print(f"Imposter CZ output state {imposter_cz(phi, theta, omega)}")
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:863, in QNode.__call__(self, *args, **kwargs)
#     860     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     862     return capture_qnode(self, *args, **kwargs)
# --> 863 return self._impl_call(*args, **kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:831, in QNode._impl_call(self, *args, **kwargs)
#     829 def _impl_call(self, *args, **kwargs) -> Result:
#     830     # construct the tape
# --> 831     tape = self.construct(args, kwargs)
#     833     # Calculate the classical jacobians if necessary
#     834     self._transform_program.set_classical_component(self, args, kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:818, in QNode.construct(self, args, kwargs)
#     816 with pldb_device_manager(self.device):
#     817     with AnnotatedQueue() as q:
# --> 818         self._qfunc_output = self.func(*args, **kwargs)
#     820 tape = QuantumScript.from_queue(q, shots)
#     822 params = tape.get_parameters(trainable_only=False)
#
# Cell In[3], line 9, in true_cz(phi, theta, omega)
#       7 @qml.qnode(device=dev)
#       8 def true_cz(phi, theta, omega):
# ----> 9     prepare_states(phi, theta, omega)
#      10
#      11     ##################
#      12     # YOUR CODE HERE #
#
# NameError: name 'prepare_states' is not defined

# %% [markdown]
# ### The SWAP gate

# %%
dev = qml.device("default.qubit", wires=2)

# Prepare a two-qubit state; change up the angles if you like
phi, theta, omega = 1.2, 2.3, 3.4


@qml.qnode(dev)
def apply_swap(phi, theta, omega):
    prepare_states(phi, theta, omega)

    ##################
    # YOUR CODE HERE #
    ##################

    # IMPLEMENT THE REGULAR SWAP GATE HERE
    qml.SWAP(wires = [0,1])
    return qml.state()


@qml.qnode(dev)
def apply_swap_with_cnots(phi, theta, omega):
    prepare_states(phi, theta, omega)

    ##################
    # YOUR CODE HERE #
    ##################

    # IMPLEMENT THE SWAP GATE USING A SEQUENCE OF CNOTS
    qml.CNOT(wires = [0,1])
    qml.CNOT(wires = [1,0])
    qml.CNOT(wires = [0,1])

    return qml.state()


print(f"Regular SWAP state = {apply_swap(phi, theta, omega)}")
print(f"CNOT SWAP state = {apply_swap_with_cnots(phi, theta, omega)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 36
#      32
#      33     return qml.state()
#      34
#      35
# ---> 36 print(f"Regular SWAP state = {apply_swap(phi, theta, omega)}")
#      37 print(f"CNOT SWAP state = {apply_swap_with_cnots(phi, theta, omega)}")
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:863, in QNode.__call__(self, *args, **kwargs)
#     860     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     862     return capture_qnode(self, *args, **kwargs)
# --> 863 return self._impl_call(*args, **kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:831, in QNode._impl_call(self, *args, **kwargs)
#     829 def _impl_call(self, *args, **kwargs) -> Result:
#     830     # construct the tape
# --> 831     tape = self.construct(args, kwargs)
#     833     # Calculate the classical jacobians if necessary
#     834     self._transform_program.set_classical_component(self, args, kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:818, in QNode.construct(self, args, kwargs)
#     816 with pldb_device_manager(self.device):
#     817     with AnnotatedQueue() as q:
# --> 818         self._qfunc_output = self.func(*args, **kwargs)
#     820 tape = QuantumScript.from_queue(q, shots)
#     822 params = tape.get_parameters(trainable_only=False)
#
# Cell In[4], line 9, in apply_swap(phi, theta, omega)
#       7 @qml.qnode(dev)
#       8 def apply_swap(phi, theta, omega):
# ----> 9     prepare_states(phi, theta, omega)
#      10
#      11     ##################
#      12     # YOUR CODE HERE #
#
# NameError: name 'prepare_states' is not defined

# %% [markdown]
# ### The Toffoli gate

# %%
dev = qml.device("default.qubit", wires=3)

# Prepare first qubit in |1>, and arbitrary states on the second two qubits
phi, theta, omega = 1.2, 2.3, 3.4


# A helper function just so you can visualize the initial state
# before the controlled SWAP occurs.
@qml.qnode(dev)
def no_swap(phi, theta, omega):
    prepare_states(phi, theta, omega)
    return qml.state()


@qml.qnode(dev)
def controlled_swap(phi, theta, omega):
    prepare_states(phi, theta, omega)

    ##################
    # YOUR CODE HERE #
    ##################

    # PERFORM A CONTROLLED SWAP USING A SEQUENCE OF TOFFOLIS
    qml.Toffoli(wires=[0, 1, 2])
    qml.Toffoli(wires=[0, 2, 1])
    qml.Toffoli(wires=[0, 1, 2])

    return qml.state()


print(no_swap(phi, theta, omega))
print(controlled_swap(phi, theta, omega))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 31
#      27
#      28     return qml.state()
#      29
#      30
# ---> 31 print(no_swap(phi, theta, omega))
#      32 print(controlled_swap(phi, theta, omega))
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:863, in QNode.__call__(self, *args, **kwargs)
#     860     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     862     return capture_qnode(self, *args, **kwargs)
# --> 863 return self._impl_call(*args, **kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:831, in QNode._impl_call(self, *args, **kwargs)
#     829 def _impl_call(self, *args, **kwargs) -> Result:
#     830     # construct the tape
# --> 831     tape = self.construct(args, kwargs)
#     833     # Calculate the classical jacobians if necessary
#     834     self._transform_program.set_classical_component(self, args, kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/Documents/applications/PythonIDE/path_env/super_quantum/lib/python3.13/site-packages/pennylane/workflow/qnode.py:818, in QNode.construct(self, args, kwargs)
#     816 with pldb_device_manager(self.device):
#     817     with AnnotatedQueue() as q:
# --> 818         self._qfunc_output = self.func(*args, **kwargs)
#     820 tape = QuantumScript.from_queue(q, shots)
#     822 params = tape.get_parameters(trainable_only=False)
#
# Cell In[5], line 11, in no_swap(phi, theta, omega)
#       9 @qml.qnode(dev)
#      10 def no_swap(phi, theta, omega):
# ---> 11     prepare_states(phi, theta, omega)
#      12     return qml.state()
#
# NameError: name 'prepare_states' is not defined

# %% [markdown]
# ### Mixed controlled state

# %%
dev = qml.device("default.qubit", wires=4)


@qml.qnode(dev)
def four_qubit_mcx():
    ##################
    # YOUR CODE HERE #
    ##################

    # IMPLEMENT THE CIRCUIT ABOVE USING A 4-QUBIT MULTI-CONTROLLED X
    qml.Hadamard(0)
    qml.Hadamard(1)
    qml.Hadamard(2)

    qml.MultiControlledX(wires=[0, 1, 2, 3], control_values=[0,0,1])

    return qml.state()


print(four_qubit_mcx())
# Out:
# [0.35355339+0.j 0.        +0.j 0.        +0.j 0.35355339+0.j
#  0.35355339+0.j 0.        +0.j 0.35355339+0.j 0.        +0.j
#  0.35355339+0.j 0.        +0.j 0.35355339+0.j 0.        +0.j
#  0.35355339+0.j 0.        +0.j 0.35355339+0.j 0.        +0.j]

# %% [markdown]
# ### The 3-controlled-NOT

# %%
# Wires 0, 1, 2 are the control qubits
# Wire 3 is the auxiliary qubit
# Wire 4 is the target
dev = qml.device("default.qubit", wires=5)


@qml.qnode(dev)
def four_qubit_mcx_only_tofs():
    # We will initialize the control qubits in state |1> so you can see
    # how the output state gets changed.
    qml.PauliX(wires=0)
    qml.PauliX(wires=1)
    qml.PauliX(wires=2)

    ##################
    # YOUR CODE HERE #
    ##################

    # IMPLEMENT A 3-CONTROLLED NOT WITH TOFFOLIS
    qml.Toffoli(wires=[0, 1, 3])
    qml.Toffoli(wires=[2, 3, 4])
    qml.Toffoli(wires=[0, 1, 3])

    return qml.state()


# print(four_qubit_mcx_only_tofs())
